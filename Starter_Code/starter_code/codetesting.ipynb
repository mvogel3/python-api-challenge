# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 620

# %%
# Set the API base URL
base_url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q=city"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}appid={weather_api_key}&units={units}&q={city}"
   
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
#     try:
        # Parse the JSON and retrieve data
    city_weather_requests = requests.get(city_url)
    city_weather = city_weather_requests.json()
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | lorengau
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | filingue
# Processing Record 9 of Set 1 | victoria
# Processing Record 10 of Set 1 | portland
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | nanchang
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | huarmey
# Processing Record 15 of Set 1 | los llanos de aridane
# Processing Record 16 of Set 1 | taolanaro
# Processing Record 17 of Set 1 | stokmarknes
# Processing Record 18 of Set 1 | belushya guba
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | sol-iletsk
# Processing Record 22 of Set 1 | tuggurt
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | yichang
# Processing Record 27 of Set 1 | dilla
# Processing Record 28 of Set 1 | saint george
# Processing Record 29 of Set 1 | ust-nera
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | mrakovo
# Processing Record 33 of Set 1 | biscarrosse
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | gladstone
# Processing Record 36 of Set 1 | pacific grove
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | husavik
# Processing Record 40 of Set 1 | marawi
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | dunedin
# Processing Record 44 of Set 1 | la ronge
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | sumbe
# Processing Record 47 of Set 1 | alice springs
# Processing Record 48 of Set 1 | anito
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | takoradi
# Processing Record 0 of Set 2 | port lincoln
# Processing Record 1 of Set 2 | sakakah
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | mys shmidta
# Processing Record 6 of Set 2 | kovdor
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | sabha
# Processing Record 9 of Set 2 | kyrylivka
# Processing Record 10 of Set 2 | puerto leguizamo
# Processing Record 11 of Set 2 | ulaanbaatar
# Processing Record 12 of Set 2 | brae
# Processing Record 13 of Set 2 | tabriz
# Processing Record 14 of Set 2 | tekax
# Processing Record 15 of Set 2 | ahipara
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | muros
# Processing Record 18 of Set 2 | tura
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | sur
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | coquimbo
# Processing Record 23 of Set 2 | chisindia
# Processing Record 24 of Set 2 | caravelas
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | meulaboh
# Processing Record 27 of Set 2 | bagdarin
# Processing Record 28 of Set 2 | liverpool
# Processing Record 29 of Set 2 | sao filipe
# Processing Record 30 of Set 2 | kununurra
# Processing Record 31 of Set 2 | peleduy
# Processing Record 32 of Set 2 | nizhneyansk
# Processing Record 33 of Set 2 | amderma
# Processing Record 34 of Set 2 | buenos aires
# Processing Record 35 of Set 2 | minot
# Processing Record 36 of Set 2 | yulara
# Processing Record 37 of Set 2 | berlevag
# Processing Record 38 of Set 2 | tasiilaq
# Processing Record 39 of Set 2 | attawapiskat
# Processing Record 40 of Set 2 | provideniya
# Processing Record 41 of Set 2 | alofi
# Processing Record 42 of Set 2 | pevek
# Processing Record 43 of Set 2 | makakilo city
# Processing Record 44 of Set 2 | great falls
# Processing Record 45 of Set 2 | yar-sale
# Processing Record 46 of Set 2 | tezu
# Processing Record 47 of Set 2 | kupang
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | san cristobal
# Processing Record 0 of Set 3 | bengkulu
# Processing Record 1 of Set 3 | norman wells
# Processing Record 2 of Set 3 | shitanjing
# Processing Record 3 of Set 3 | talnakh
# Processing Record 4 of Set 3 | khatanga
# Processing Record 5 of Set 3 | puksoozero
# Processing Record 6 of Set 3 | marcona
# Processing Record 7 of Set 3 | kavieng
# Processing Record 8 of Set 3 | ucluelet
# Processing Record 9 of Set 3 | hithadhoo
# Processing Record 10 of Set 3 | saint-augustin
# Processing Record 11 of Set 3 | pirogovo
# Processing Record 12 of Set 3 | kristiinankaupunki
# Processing Record 13 of Set 3 | broome
# Processing Record 14 of Set 3 | meadow lake
# Processing Record 15 of Set 3 | mahadday weyne
# Processing Record 16 of Set 3 | katsiveli
# Processing Record 17 of Set 3 | touros
# Processing Record 18 of Set 3 | chapais
# Processing Record 19 of Set 3 | beringovskiy
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | caucaia
# Processing Record 22 of Set 3 | lynn haven
# Processing Record 23 of Set 3 | iqaluit
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | lishan
# Processing Record 26 of Set 3 | bilma
# Processing Record 27 of Set 3 | nome
# Processing Record 28 of Set 3 | narasannapeta
# Processing Record 29 of Set 3 | guerrero negro
# Processing Record 30 of Set 3 | bargal
# Processing Record 31 of Set 3 | lat yao
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | vila velha
# Processing Record 34 of Set 3 | mar del plata
# Processing Record 35 of Set 3 | nizhneivkino
# Processing Record 36 of Set 3 | kahului
# Processing Record 37 of Set 3 | illoqqortoormiut
# Processing Record 38 of Set 3 | cidreira
# Processing Record 39 of Set 3 | gat
# Processing Record 40 of Set 3 | doctor juan manuel frutos
# Processing Record 41 of Set 3 | pueblo
# Processing Record 42 of Set 3 | bathsheba
# Processing Record 43 of Set 3 | tiznit
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | bobigny
# Processing Record 46 of Set 3 | pineville
# Processing Record 47 of Set 3 | lexington
# Processing Record 48 of Set 3 | tilichiki
# Processing Record 49 of Set 3 | taoudenni
# Processing Record 0 of Set 4 | nowy targ
# Processing Record 1 of Set 4 | barentsburg
# Processing Record 2 of Set 4 | ilhabela
# Processing Record 3 of Set 4 | tuktoyaktuk
# Processing Record 4 of Set 4 | cuamba
# Processing Record 5 of Set 4 | hambantota
# Processing Record 6 of Set 4 | quatre cocos
# Processing Record 7 of Set 4 | hami
# Processing Record 8 of Set 4 | hobyo
# Processing Record 9 of Set 4 | lebu
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | port hardy
# Processing Record 12 of Set 4 | falkoping
# Processing Record 13 of Set 4 | itacoatiara
# Processing Record 14 of Set 4 | pochutla
# Processing Record 15 of Set 4 | bud
# Processing Record 16 of Set 4 | korla
# Processing Record 17 of Set 4 | mugumu
# Processing Record 18 of Set 4 | toliary
# Processing Record 19 of Set 4 | kedrovyy
# Processing Record 20 of Set 4 | hobart
# Processing Record 21 of Set 4 | palmer
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | jizan
# Processing Record 24 of Set 4 | sioux lookout
# Processing Record 25 of Set 4 | kosikha
# Processing Record 26 of Set 4 | ulaangom
# Processing Record 27 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 4 | upernavik
# Processing Record 29 of Set 4 | aswan
# Processing Record 30 of Set 4 | kutum
# Processing Record 31 of Set 4 | belyy yar
# Processing Record 32 of Set 4 | mehamn
# Processing Record 33 of Set 4 | ilulissat
# Processing Record 34 of Set 4 | saint-joseph
# Processing Record 35 of Set 4 | san patricio
# Processing Record 36 of Set 4 | bethel
# Processing Record 37 of Set 4 | ancud
# Processing Record 38 of Set 4 | visby
# Processing Record 39 of Set 4 | padang
# Processing Record 40 of Set 4 | russell
# Processing Record 41 of Set 4 | nenjiang
# Processing Record 42 of Set 4 | cockburn town
# Processing Record 43 of Set 4 | santa marta
# Processing Record 44 of Set 4 | ingham
# Processing Record 45 of Set 4 | tongren
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | humberto de campos
# Processing Record 48 of Set 4 | praia
# Processing Record 49 of Set 4 | la orilla
# Processing Record 0 of Set 5 | sitka
# Processing Record 1 of Set 5 | coihaique
# Processing Record 2 of Set 5 | yokadouma
# Processing Record 3 of Set 5 | mao
# Processing Record 4 of Set 5 | rawson
# Processing Record 5 of Set 5 | panalingaan
# Processing Record 6 of Set 5 | tigil
# Processing Record 7 of Set 5 | geraldton
# Processing Record 8 of Set 5 | jamestown
# Processing Record 9 of Set 5 | haines junction
# Processing Record 10 of Set 5 | umzimvubu
# Processing Record 11 of Set 5 | koygorodok
# Processing Record 12 of Set 5 | grindavik
# Processing Record 13 of Set 5 | longyearbyen
# Processing Record 14 of Set 5 | nikolskoye
# Processing Record 15 of Set 5 | asau
# Processing Record 16 of Set 5 | qaanaaq
# Processing Record 17 of Set 5 | calama
# Processing Record 18 of Set 5 | angul
# Processing Record 19 of Set 5 | sao joao da barra
# Processing Record 20 of Set 5 | leningradskiy
# Processing Record 21 of Set 5 | puerto ayora
# Processing Record 22 of Set 5 | mehran
# Processing Record 23 of Set 5 | wuda
# Processing Record 24 of Set 5 | sorong
# Processing Record 25 of Set 5 | klaksvik
# Processing Record 26 of Set 5 | grand river south east
# Processing Record 27 of Set 5 | southbridge
# Processing Record 28 of Set 5 | veraval
# Processing Record 29 of Set 5 | anta
# Processing Record 30 of Set 5 | olinda
# Processing Record 31 of Set 5 | hay river
# Processing Record 32 of Set 5 | saint anthony
# Processing Record 33 of Set 5 | buala
# Processing Record 34 of Set 5 | manitouwadge
# Processing Record 35 of Set 5 | ligayan
# Processing Record 36 of Set 5 | sakaraha
# Processing Record 37 of Set 5 | jalu
# Processing Record 38 of Set 5 | port townsend
# Processing Record 39 of Set 5 | saskylakh
# Processing Record 40 of Set 5 | elat
# Processing Record 41 of Set 5 | verkhnevilyuysk
# Processing Record 42 of Set 5 | virginia beach
# Processing Record 43 of Set 5 | tessalit
# Processing Record 44 of Set 5 | houlton
# Processing Record 45 of Set 5 | berezovyy
# Processing Record 46 of Set 5 | presidencia roque saenz pena
# Processing Record 47 of Set 5 | mitsamiouli
# Processing Record 48 of Set 5 | znamenskoye
# Processing Record 49 of Set 5 | barrow
# Processing Record 0 of Set 6 | north platte
# Processing Record 1 of Set 6 | shelopugino
# Processing Record 2 of Set 6 | edd
# Processing Record 3 of Set 6 | ushtobe
# Processing Record 4 of Set 6 | sao jose da coroa grande
# Processing Record 5 of Set 6 | east london
# Processing Record 6 of Set 6 | cape town
# Processing Record 7 of Set 6 | katobu
# Processing Record 8 of Set 6 | orlik
# Processing Record 9 of Set 6 | vila franca do campo
# Processing Record 10 of Set 6 | vagay
# Processing Record 11 of Set 6 | whitecourt
# Processing Record 12 of Set 6 | tobol
# Processing Record 13 of Set 6 | khorinsk
# Processing Record 14 of Set 6 | waipawa
# Processing Record 15 of Set 6 | hasaki
# Processing Record 16 of Set 6 | broken hill
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | winnemucca
# Processing Record 19 of Set 6 | chandbali
# Processing Record 20 of Set 6 | santiago del estero
# Processing Record 21 of Set 6 | vostok
# Processing Record 22 of Set 6 | cabano
# Processing Record 23 of Set 6 | jati
# Processing Record 24 of Set 6 | palabuhanratu
# Processing Record 25 of Set 6 | troitsko-pechorsk
# Processing Record 26 of Set 6 | oktyabrskiy
# Processing Record 27 of Set 6 | dillon
# Processing Record 28 of Set 6 | krasnoselkup
# Processing Record 29 of Set 6 | adre
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | carnarvon
# Processing Record 32 of Set 6 | bambous virieux
# Processing Record 33 of Set 6 | mount gambier
# Processing Record 34 of Set 6 | boende
# Processing Record 35 of Set 6 | kashi
# Processing Record 36 of Set 6 | nchelenge
# Processing Record 37 of Set 6 | kemi
# Processing Record 38 of Set 6 | faanui
# Processing Record 39 of Set 6 | bakuriani
# Processing Record 40 of Set 6 | mananjary
# Processing Record 41 of Set 6 | daru
# Processing Record 42 of Set 6 | ladovskaya balka
# Processing Record 43 of Set 6 | kampene
# Processing Record 44 of Set 6 | gazojak
# Processing Record 45 of Set 6 | quelimane
# Processing Record 46 of Set 6 | dzaoudzi
# Processing Record 47 of Set 6 | kudahuvadhoo
# Processing Record 48 of Set 6 | pontianak
# Processing Record 49 of Set 6 | xicotencatl
# Processing Record 0 of Set 7 | westport
# Processing Record 1 of Set 7 | sentyabrskiy
# Processing Record 2 of Set 7 | anadyr
# Processing Record 3 of Set 7 | sinop
# Processing Record 4 of Set 7 | ca mau
# Processing Record 5 of Set 7 | tual
# Processing Record 6 of Set 7 | abnub
# Processing Record 7 of Set 7 | vaitape
# Processing Record 8 of Set 7 | harrison
# Processing Record 9 of Set 7 | parrita
# Processing Record 10 of Set 7 | yarensk
# Processing Record 11 of Set 7 | namatanai
# Processing Record 12 of Set 7 | banda aceh
# Processing Record 13 of Set 7 | vestmannaeyjar
# Processing Record 14 of Set 7 | abu samrah
# Processing Record 15 of Set 7 | avera
# Processing Record 16 of Set 7 | tecoanapa
# Processing Record 17 of Set 7 | naifaru
# Processing Record 18 of Set 7 | kazalinsk
# Processing Record 19 of Set 7 | cayenne
# Processing Record 20 of Set 7 | andenes
# Processing Record 21 of Set 7 | maniitsoq
# Processing Record 22 of Set 7 | nanortalik
# Processing Record 23 of Set 7 | boa vista
# Processing Record 24 of Set 7 | kamenka
# Processing Record 25 of Set 7 | allapalli
# Processing Record 26 of Set 7 | yinchuan
# Processing Record 27 of Set 7 | vicuna
# Processing Record 28 of Set 7 | narsaq
# Processing Record 29 of Set 7 | araripina
# Processing Record 30 of Set 7 | saint-georges
# Processing Record 31 of Set 7 | carutapera
# Processing Record 32 of Set 7 | afmadu
# Processing Record 33 of Set 7 | bairiki
# Processing Record 34 of Set 7 | natal
# Processing Record 35 of Set 7 | tignere
# Processing Record 36 of Set 7 | aflu
# Processing Record 37 of Set 7 | vyartsilya
# Processing Record 38 of Set 7 | port hedland
# Processing Record 39 of Set 7 | jaisalmer
# Processing Record 40 of Set 7 | kargasok
# Processing Record 41 of Set 7 | praia da vitoria
# Processing Record 42 of Set 7 | jaru
# Processing Record 43 of Set 7 | kruisfontein
# Processing Record 44 of Set 7 | mayo
# Processing Record 45 of Set 7 | sawakin
# Processing Record 46 of Set 7 | peniche
# Processing Record 47 of Set 7 | moranbah
# Processing Record 48 of Set 7 | belmonte
# Processing Record 49 of Set 7 | lompoc
# Processing Record 0 of Set 8 | karratha
# Processing Record 1 of Set 8 | barhi
# Processing Record 2 of Set 8 | puerto maldonado
# Processing Record 3 of Set 8 | veurne
# Processing Record 4 of Set 8 | surt
# Processing Record 5 of Set 8 | gomel
# Processing Record 6 of Set 8 | isangel
# Processing Record 7 of Set 8 | oistins
# Processing Record 8 of Set 8 | acapulco
# Processing Record 9 of Set 8 | prattville
# Processing Record 10 of Set 8 | yancheng
# Processing Record 11 of Set 8 | katangli
# Processing Record 12 of Set 8 | sinnamary
# Processing Record 13 of Set 8 | tumannyy
# Processing Record 14 of Set 8 | hirara
# Processing Record 15 of Set 8 | atka
# Processing Record 16 of Set 8 | qaqortoq
# Processing Record 17 of Set 8 | caramay
# Processing Record 18 of Set 8 | sassandra
# Processing Record 19 of Set 8 | coria
# Processing Record 20 of Set 8 | uruguaiana
# Processing Record 21 of Set 8 | panjab
# Processing Record 22 of Set 8 | artyk
# Processing Record 23 of Set 8 | hamilton
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | wenling
# Processing Record 26 of Set 8 | lang son
# Processing Record 27 of Set 8 | kachikau
# Processing Record 28 of Set 8 | along
# Processing Record 29 of Set 8 | kuna
# Processing Record 30 of Set 8 | fomboni
# Processing Record 31 of Set 8 | maragogi
# Processing Record 32 of Set 8 | la asuncion
# Processing Record 33 of Set 8 | kasongo-lunda
# Processing Record 34 of Set 8 | souillac
# Processing Record 35 of Set 8 | mana
# Processing Record 36 of Set 8 | muhoroni
# Processing Record 37 of Set 8 | puerto del rosario
# Processing Record 38 of Set 8 | port macquarie
# Processing Record 39 of Set 8 | moron
# Processing Record 40 of Set 8 | halalo
# Processing Record 41 of Set 8 | grand gaube
# Processing Record 42 of Set 8 | port hawkesbury
# Processing Record 43 of Set 8 | lubao
# Processing Record 44 of Set 8 | pueblo nuevo
# Processing Record 45 of Set 8 | buritizeiro
# Processing Record 46 of Set 8 | akureyri
# Processing Record 47 of Set 8 | henties bay
# Processing Record 48 of Set 8 | pafos
# Processing Record 49 of Set 8 | hovd
# Processing Record 0 of Set 9 | medicine hat
# Processing Record 1 of Set 9 | shache
# Processing Record 2 of Set 9 | sarkand
# Processing Record 3 of Set 9 | dakar
# Processing Record 4 of Set 9 | qinggang
# Processing Record 5 of Set 9 | manoel urbano
# Processing Record 6 of Set 9 | oudtshoorn
# Processing Record 7 of Set 9 | whitehorse
# Processing Record 8 of Set 9 | katsuura
# Processing Record 9 of Set 9 | khor
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/p1/75d6qxbd65v17kwgc_pn1k7w0000gn/T/ipykernel_57425/1867288176.py in <module>
#      36 #     try:
#      37         # Parse the JSON and retrieve data
# ---> 38     city_weather_requests = requests.get(city_url)
#      39     city_weather = city_weather_requests.json()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497                     decode_content=False,
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#     501
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
city_weather
